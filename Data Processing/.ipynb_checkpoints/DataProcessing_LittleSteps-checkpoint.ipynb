# %% [markdown]
# # DATA PROCESSING
#
# <b>This file contains the data cleaning and processing codes for the Little Steps project. All codes have been run on the raw "visits_raw.csv" dataset.<br></b>
#
# The codes include cleaning operations as well as feature engineering operations.<br>
#
# The output is a cleaned and feature engineered csv file "visits_clean.csv".

# %% [markdown]
# ## 1. Importing Necessary Libraries

# %%
#Pandas will be useful for storing imported data in the form a dataframe which will be useful for cleaning and observing the data
import pandas as pd 

#Other libraries will be included on a need basis

# %% [markdown]
# ## 2. Importing Raw Dataset for Observation

# %%
#Reading the raw data file and storing it in a variable "visits_raw" as a dataframe
visits_raw = pd.read_csv(r"C:\Users\risha\Desktop\Speedoc Data Intern Assignment\GitHub Repository\LittleSteps_Assignment_SpeedocPteLtd_DataIntern\Datasets\visits_raw.csv")

# %%
#Understanding a rough view of the data using .head() function
visits_raw.head()
# Out:
#                                visit_id patient_id nurse_id  \
# 0  6a4a715f-94c5-4b5d-8f51-51f07f298fb6     P59581    N1565
# 1  27bfc4de-9dd2-4b6b-b05f-f9560a3fd00f     P66547    N5698
# 2  9c2d0018-8f20-4789-a383-906d49042fbc     P47919    N3012
# 3  bbedc08d-0ada-4c8f-bac4-3008ac279a01     P18359    N8991
# 4  155c3765-22d5-41cc-95f5-a94ef19748ae     P45602    N7948
#
#           visit_start_time           visit_end_time      service_type  \
# 0      2025-09-02 00:08:24      2025-09-02 00:55:24        Wound Care
# 1  August 24, 2025 10:42PM  August 25, 2025 12:12AM  General Check-up
# 2      2025-09-02 11:07:33         2025/09/02 11:56  Physical Therapy
# 3      2025-09-15 21:24:42      2025-09-15 22:12:42  General Check-up
# 4      2025-08-31 07:19:11      2025-08-31 07:47:11  Pyhcisal Therapy
#
#   visit_location                                        nurse_notes
# 0           East  The nurse changed the wound dressing. The pati...
# ...
